# %%
import pandas as pd

# %%
#데이터 불러오기 
daeduckgu_park = pd.read_csv('G:/bigdata/daeduckgu_park.csv', encoding = 'cp949')
donggu_park = pd.read_csv('G:/bigdata/donggu_park.csv',encoding ='cp949')
junggu_park = pd.read_csv('G:/bigdata/junggu_park.csv',encoding ='cp949')
seogu_park = pd.read_csv('G:/bigdata/seogu_park.csv',encoding ='cp949')
yuseonggu_park = pd.read_csv('G:/bigdata/yuseong_park.csv',encoding ='cp949')

# %%
donggu_park.columns
# Out:
# Index(['관리번호', '공원명', '공원구분', '소재지도로명주소', '소재지지번주소', '위도', '경도', '공원면적',
#        '공원보유시설(운동시설)', '공원보유시설(유희시설)', '공원보유시설(편익시설)', '공원보유시설(교양시설)',
#        '공원보유시설(기타시설)', '지정고시일', '관리기관명', '전화번호', '데이터기준일자'],
#       dtype='object')

# %%
daeduckgu_park.columns
# Out:
# Index(['관리번호', '공원명', '공원구분', '소재지도로명주소', '소재지지번주소', '위도', '경도', '공원면적',
#        '공원보유시설(운동시설)', '공원보유시설(유희시설)', '공원보유시설(편익시설)', '공원보유시설(교양시설)',
#        '공원보유시설(기타시설)', '지정고시일', '관리기관명', '전화번호', '데이터기준일자'],
#       dtype='object')

# %% [markdown]
# 변수명이 다 통일되어 있음

# %%
#변수명이 다 같으므로 밑으로 연결
daejeon_park = pd.concat([daeduckgu_park, donggu_park, junggu_park, seogu_park, yuseonggu_park])

# %%
daejeon_park.head(3)
# Out:
#           관리번호 공원명  공원구분                   소재지도로명주소              소재지지번주소  \
# 0  30230-00001  중리  근린공원  대전광역시 대덕구 중리동로41번길28(중리동)  대전광역시 대덕구 중리동388-17
# 1  30230-00002  쌍청  근린공원    대전광역시 대덕구 쌍청당로 25 (중리동)   대전광역시 대덕구 중리동101-1
# 2  30230-00003  안산  근린공원   대전광역시 대덕구 계족로663번길25(법동)    대전광역시 대덕구 법동284-2
#
#           위도          경도     공원면적 공원보유시설(운동시설) 공원보유시설(유희시설) 공원보유시설(편익시설)  \
# 0  36.362813  127.427324  10322.0  농구골대,평행봉,철봉        조합놀이대   평의자,평상,화장실
# 1  36.364331  127.433561  17713.0       야외운동기구        조합놀이대   평의자,평상,화장실
# 2  36.368430  127.426419  13520.0       평행봉,철봉          NaN      평의자,지압로
#
#   공원보유시설(교양시설) 공원보유시설(기타시설)       지정고시일       관리기관명          전화번호     데이터기준일자
# 0          NaN          NaN  1984-08-20  대전광역시 대덕구청  042-608-5134  2021-06-29
# 1       청소년수련관          NaN  1984-08-20  대전광역시 대덕구청  042-608-5134  2021-06-29
# 2    안산평생학습도서관          NaN  1984-08-20  대전광역시 대덕구청  042-608-5134  2021-06-29

# %%
# 행과 열 개수를 가져옴 
print(daeduckgu_park.shape,
donggu_park.shape,
junggu_park.shape,
seogu_park.shape,
yuseonggu_park.shape)
# Out:
# (82, 17) (117, 17) (47, 17) (108, 17) (144, 17)

# %%
daejeon_park.shape
# Out:
# (498, 17)

# %%
daejeon_park['소재지지번주소'].head() #어느 구인지 변수를 추가하기 위해서
# Out:
# 0    대전광역시 대덕구 중리동388-17
# 1     대전광역시 대덕구 중리동101-1
# 2      대전광역시 대덕구 법동284-2
# 3      대전광역시 대덕구 문평동42-4
# 4      대전광역시 대덕구 문평동78-5
# Name: 소재지지번주소, dtype: object

# %%
gu = [] #빈 리스트 생성 
for gu1 in daejeon_park['소재지지번주소']: 
    gu1 = gu1[5:9] # ex> 대전광역시 대덕구 중리동388-17의 5번째부터 9번쨰 글자를 가져옴 
    gu1 = gu1.replace(" ","") #공백을 공백없음으로 바꿔줌 " 대덕구" " 중구 " 이런식으로 가져와짐 -> replace함수는 공백을 제거하기 위해서 사용
    gu.append(gu1) #뽑아온 문자열을 gu이라는 리스트에 저장

# %%
gu
# Out:
# ['대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '대덕구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '동구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '서구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구',
#  '유성구']

# %%
daejeon_park['gu'] = gu # 동 변수 추가(맨마지막열)

# %%
daejeon_park.head(2)
# Out:
#           관리번호 공원명  공원구분                   소재지도로명주소              소재지지번주소  \
# 0  30230-00001  중리  근린공원  대전광역시 대덕구 중리동로41번길28(중리동)  대전광역시 대덕구 중리동388-17
# 1  30230-00002  쌍청  근린공원    대전광역시 대덕구 쌍청당로 25 (중리동)   대전광역시 대덕구 중리동101-1
#
#           위도          경도     공원면적 공원보유시설(운동시설) 공원보유시설(유희시설) 공원보유시설(편익시설)  \
# 0  36.362813  127.427324  10322.0  농구골대,평행봉,철봉        조합놀이대   평의자,평상,화장실
# 1  36.364331  127.433561  17713.0       야외운동기구        조합놀이대   평의자,평상,화장실
#
#   공원보유시설(교양시설) 공원보유시설(기타시설)       지정고시일       관리기관명          전화번호     데이터기준일자  \
# 0          NaN          NaN  1984-08-20  대전광역시 대덕구청  042-608-5134  2021-06-29
# 1       청소년수련관          NaN  1984-08-20  대전광역시 대덕구청  042-608-5134  2021-06-29
#
#     gu
# 0  대덕구
# 1  대덕구

# %%
#해당 경로에 csv로 저장 
daejeon_park.to_csv('G:/bigdata/daejeon_park.csv', encoding ='cp949')
